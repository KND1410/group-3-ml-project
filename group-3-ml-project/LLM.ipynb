# %% [markdown]
# # Creating LLM

# %%
# !pip install google-genai python-dotenv

# %% [markdown]
# ### Create and save your own API in .env with GEMINI_API=AIza..., remember to put .env in .gitignore

# %%
from google import genai
from dotenv import load_dotenv
import os

reviews_sample = X_test.iloc[:50]
labels_sample = y_test.iloc[:50]

load_dotenv()
client = genai.Client(api_key=os.getenv("GEMINI_API"))

gemini_predictions = []

for review in reviews_sample:
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=f"""Read this movie review and reply with ONLY one word: 
        'positive' or 'negative'.
        
        Review: {review}"""
    )
    
    answer = response.text.strip().lower()
    if 'positive' in answer:
        gemini_predictions.append(1)
    else:
        gemini_predictions.append(0)

gemini_accuracy = accuracy_score(labels_sample, gemini_predictions)
print(f"Gemini accuracy: {gemini_accuracy:.2%}")

print(f"Naive Bayes : {nb_accuracy:.2%}")
print(f"Gemini      : {gemini_accuracy:.2%}")

if nb_accuracy > gemini_accuracy:
    print("→ Classical ML thắng!")
else:
    print("→ LLM thắng!")

print(response.text)
