# %% [markdown]
# # Creating LLM

# %%
#!pip install google-genai python-dotenv

# %% [markdown]
# ### Create and save your own API in .env with GEMINI_API=AIza..., remember to put .env in .gitignore

# %%
from google import genai
from dotenv import load_dotenv
import os

load_dotenv()
client = genai.Client(api_key=os.getenv("GEMINI_API"))
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="I have the IMDB movie review dataset (50k reviews, binary sentiment: positive/negative). Suggest 5 specific features I could engineer from the raw review text to improve the model."
)

print(response.text)
# Out:
# Here are 5 specific features you could engineer from raw IMDB movie review text, designed to capture nuances beyond simple Bag-of-Words or TF-IDF, specifically for improving binary sentiment classification:
#
# ---
#
# 1.  **Sentiment Lexicon-based Features (Counts and Ratios)**
#
#     *   **Description:** Use pre-existing sentiment lexicons (e.g., AFINN, Bing Liu, MPQA, SentiWordNet) to identify and count positive and negative words within each review. You could extract:
#         *   `num_positive_words`: Count of words classified as positive.
#         *   `num_negative_words`: Count of words classified as negative.
#         *   `positive_to_negative_ratio`: `num_positive_words` / (`num_negative_words` + 1) (add 1 to avoid division by zero).
#         *   `net_sentiment_score`: A sum of scores if your lexicon provides them (e.g., AFINN assigns -5 to +5).
#     *   **Why it helps:** Directly quantifies the presence of opinionated language. A higher ratio of positive words generally indicates a positive review, and vice-versa. These features provide a strong, interpretable signal of the underlying sentiment.
#     *   **Implementation:** Tokenize the review, then iterate through tokens, checking if each token exists in your chosen sentiment lexicon(s) and incrementing respective counts.
#
# 2.  **Negation Features (Count of Negated Sentiment Terms)**
#
#     *   **Description:** Identify instances where a sentiment-bearing word is negated. Examples include "not good," "never happy," "didn't like," "no fun." This feature could be:
#         *   `num_negated_positive_words`: Count of positive words preceded by a negation word (e.g., "not good," "didn't enjoy").
#         *   `num_negated_negative_words`: Count of negative words preceded by a negation word (e.g., "not bad," "didn't hate").
#     *   **Why it helps:** Negation fundamentally flips the sentiment of a word or phrase. A simple Bag-of-Words model would see "good" and "not good" as equally contributing to "goodness," which is incorrect. This feature specifically addresses that semantic reversal. "Not bad" is often a positive statement.
#     *   **Implementation:** Requires POS tagging or a dependency parser to accurately identify negation scope, but a simpler approach involves looking for common negation words (e.g., "not", "no", "never", "didn't", "don't", "isn't", "aren't") within a certain window (e.g., 1-3 words) before a known sentiment word.
#
# 3.  **Intensifiers/De-intensifiers (Adverbial Modifiers)**
#
#     *   **Description:** Count the occurrences of adverbs that either strengthen (intensifiers) or weaken (de-intensifiers) the sentiment of an adjacent adjective or verb.
#         *   `num_intensifiers`: Count of words like "very," "extremely," "really," "so," "quite," "terribly" (when preceding a sentiment word).
#         *   `num_deintensifiers`: Count of words like "somewhat," "slightly," "barely," "hardly," "a bit" (when preceding a sentiment word).
#     *   **Why it helps:** Differentiates between mild and strong opinions. "Good" is positive, but "very good" is *more* positive, and "somewhat good" is *less* positive. These modifiers significantly impact the strength of the expressed sentiment.
#     *   **Implementation:** Create lists of common intensifiers and de-intensifiers. Then, for each review, find instances where these modifiers appear immediately before or after a known sentiment word (using a sentiment lexicon).
#
# 4.  **Excessive Punctuation and Capitalization**
#
#     *   **Description:** Quantify the emotional intensity indicated by specific punctuation and text formatting.
#         *   `num_exclamation_marks`: Count of `!` characters.
#         *   `num_question_marks`: Count of `?` characters (can indicate doubt or strong rhetorical questions).
#         *   `num_all_caps_words`: Count of words written entirely in uppercase (excluding short words like "I", "A").
#         *   `num_emojis_or_emoticons`: While less common in formal movie reviews, if present, these are strong sentiment signals.
#     *   **Why it helps:** People use these stylistic choices to convey strong emotions, excitement, anger, or emphasis. A review with many exclamation marks and all-caps words is highly likely to be expressing strong positive or negative feelings, rather than a neutral one.
#     *   **Implementation:** Simple string parsing to count occurrences of `!`, `?`. For all-caps words, split the review into words, then check `word.isupper()` and filter out very short words.
#
# 5.  **Review Length (Word Count / Sentence Count)**
#
#     *   **Description:** Simple numerical features representing the length and structure of the review.
#         *   `review_word_count`: Total number of words in the review.
#         *   `review_sentence_count`: Total number of sentences in the review.
#         *   `avg_sentence_length`: `review_word_count` / `review_sentence_count`.
#     *   **Why it helps:** Review length can sometimes correlate with sentiment or engagement. Very short reviews might be blunt (e.g., "Terrible movie.") while very long reviews might offer detailed critiques, often leaning strongly one way or the other. Extremely short reviews can be hard for models to classify accurately due to limited textual context, so this feature gives the model a hint about the available information density.
#     *   **Implementation:** Tokenize the review into words and sentences (e.g., using NLTK's `word_tokenize` and `sent_tokenize`).
#
# ---
#
# By incorporating these features, your model will have explicit signals about the emotional content, intensity, and structural characteristics of each review, leading to a more robust and accurate sentiment classification.
