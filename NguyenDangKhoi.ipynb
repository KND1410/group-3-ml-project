# %%
from google import genai
from dotenv import load_dotenv
import os

load_dotenv()
client = os.getenv("GEMINI_API")
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="I have the IMDB movie review dataset (50k reviews, binary sentiment: positive/negative). Suggest 5 specific features I could engineer from the raw review text to improve the model."
)

print('response.text')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 8
#       4
#       5 load_dotenv()
#       6 api_key = os.getenv("GEMINI_API_KEY")
#       7
# ----> 8 response = client.models.generate_content(
#       9     model="gemini-2.5-flash",
#      10     contents="I have the IMDB movie review dataset (50k reviews, binary sentiment: positive/negative). Suggest 5 specific features I could engineer from the raw review text to improve the model."
#      11 )
#
# NameError: name 'client' is not defined
