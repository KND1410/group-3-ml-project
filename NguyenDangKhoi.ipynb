# %%
from google import genai
from dotenv import load_dotenv
import os

load_dotenv()
client = genai.Client(api_key=os.getenv("GEMINI_API"))
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="I have the IMDB movie review dataset (50k reviews, binary sentiment: positive/negative). Suggest 5 specific features I could engineer from the raw review text to improve the model."
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 7
#       3 import os
#       4
#       5 load_dotenv()
#       6 client = os.getenv("GEMINI_API")
# ----> 7 response = client.models.generate_content(
#       8     model="gemini-2.5-flash",
#       9     contents="I have the IMDB movie review dataset (50k reviews, binary sentiment: positive/negative). Suggest 5 specific features I could engineer from the raw review text to improve the model."
#      10 )
#
# AttributeError: 'str' object has no attribute 'models'
